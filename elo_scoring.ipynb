# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load in csv 

df = pd.read_csv('data/nfl_games.csv')

df.tail(5)
# Out:
#             date  season  neutral  playoff team1 team2         elo1  \
# 15735  1/15/2017    2016        0        1   DAL    GB  1617.794683
# 15736  1/15/2017    2016        0        1    KC   PIT  1681.926463
# 15737  1/22/2017    2016        0        1   ATL    GB  1664.127266
# 15738  1/22/2017    2016        0        1    NE   PIT  1747.160321
# 15739   2/5/2017    2016        1        1   ATL    NE  1688.081418
#
#               elo2  elo_prob1  score1  score2  result1
# 15735  1635.451172   0.567714      31      34      0.0
# 15736  1647.734179   0.638993      16      18      0.0
# 15737  1651.537731   0.609840      44      21      1.0
# 15738  1662.437215   0.703052      36      17      1.0
# 15739  1763.818168   0.392700      28      34      0.0

# %%
# check datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15740 entries, 0 to 15739
# Data columns (total 12 columns):
# date         15740 non-null object
# season       15740 non-null int64
# neutral      15740 non-null int64
# playoff      15740 non-null int64
# team1        15740 non-null object
# team2        15740 non-null object
# elo1         15740 non-null float64
# elo2         15740 non-null float64
# elo_prob1    15740 non-null float64
# score1       15740 non-null int64
# score2       15740 non-null int64
# result1      15740 non-null float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 1.4+ MB

# %%
# limit data to the previous 3 seasons & non-playoff (regular season) games
df = df[df['season']>2013]
df = df[df['playoff']==0]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 768 entries, 14939 to 15728
# Data columns (total 12 columns):
# date         768 non-null object
# season       768 non-null int64
# neutral      768 non-null int64
# playoff      768 non-null int64
# team1        768 non-null object
# team2        768 non-null object
# elo1         768 non-null float64
# elo2         768 non-null float64
# elo_prob1    768 non-null float64
# score1       768 non-null int64
# score2       768 non-null int64
# result1      768 non-null float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 78.0+ KB

# %%
# check for empty entries
df.isnull().sum()
# Out:
# date         0
# season       0
# neutral      0
# playoff      0
# team1        0
# team2        0
# elo1         0
# elo2         0
# elo_prob1    0
# score1       0
# score2       0
# result1      0
# dtype: int64

# %%
# Add datetime column

df['datetime'] = pd.to_datetime(df['date'])

# Add elo_prob2 column

df['elo_prob2'] = 1-pd.to_numeric(df['elo_prob1'])

# parse dataset by team, elo scores, and elo probabilities

split_t1 = df[['date','datetime','season','team1','elo1','elo_prob1']]
split_t2 = df[['date','datetime','season','team2','elo2','elo_prob2']]

split_t1.columns = ['date','datetime','season','team','elo','probability']
split_t2.columns = ['date','datetime','season','team','elo','probability']

merge_df = [split_t1,split_t2]
merged = pd.concat(merge_df)

# %%
merged['team'].unique()
# Out:
# array(['SEA', 'PHI', 'PIT', 'BAL', 'TB', 'DEN', 'LAR', 'ATL', 'CHI', 'DAL',
#        'HOU', 'KC', 'MIA', 'NYJ', 'ARI', 'DET', 'BUF', 'CAR', 'CIN', 'WSH',
#        'CLE', 'GB', 'MIN', 'SF', 'NYG', 'LAC', 'TEN', 'OAK', 'IND', 'JAX',
#        'NO', 'NE'], dtype=object)

# %%
# add conference and division
afc_teams =['BUF','MIA','NE','NYJ',
            'BAL','CIN','CLE','PIT',
            'HOU','IND','JAX','TEN',
            'DEN','KC','LAC','OAK']
nfc_teams =['DAL','NYG','PHI','WSH',
            'CHI','DET','GB','MIN',
            'ATL','CAR','NO','TB',
            'ARI','LAR','SF','SEA']
afceast = ['BUF','MIA','NE','NYJ']
afcnorth = ['BAL','CIN','CLE','PIT']
afcsouth = ['HOU','IND','JAX','TEN']
afcwest = ['DEN','KC','LAC','OAK']
nfceast = ['DAL','NYG','PHI','WSH']
nfcnorth = ['CHI','DET','GB','MIN']
nfcsouth = ['ATL','CAR','NO','TB']
nfcwest = ['ARI','LAR','SF','SEA']

merged['conference'] = np.where(merged['team'].isin(afc_teams), 'AFC',
                                np.where(merged['team'].isin(nfc_teams), 'NFC',''))
merged['division'] = np.where(merged['team'].isin(afceast), 'AFC East',(
                        np.where(merged['team'].isin(afcnorth), 'AFC North',
                           np.where(merged['team'].isin(afcsouth), 'AFC South',
                                np.where(merged['team'].isin(afcwest), 'AFC West',
                                    np.where(merged['team'].isin(nfceast), 'NFC East',
                                        np.where(merged['team'].isin(nfcnorth), 'NFC North',
                                            np.where(merged['team'].isin(nfcsouth), 'NFC South',
                                                np.where(merged['team'].isin(nfcwest), 'NFC West','')))))))))

# %%
merged.sort_values(['season','datetime','probability'],ascending=[True,True,False])
merged.reset_index(inplace=True, drop=True)
merged
# Out:
#             date   datetime  season team          elo  probability conference  \
# 0       9/4/2014 2014-09-04    2014  SEA  1678.971000     0.803040        NFC
# 1       9/7/2014 2014-09-07    2014  PHI  1528.197000     0.791858        NFC
# 2       9/7/2014 2014-09-07    2014  PIT  1537.231000     0.772161        AFC
# 3       9/7/2014 2014-09-07    2014  BAL  1529.779000     0.549330        AFC
# 4       9/7/2014 2014-09-07    2014   TB  1436.161000     0.392988        NFC
# 5       9/7/2014 2014-09-07    2014  DEN  1624.090000     0.702028        AFC
# 6       9/7/2014 2014-09-07    2014  LAR  1512.750000     0.643936        NFC
# 7       9/7/2014 2014-09-07    2014  ATL  1458.825000     0.428661        NFC
# 8       9/7/2014 2014-09-07    2014  CHI  1493.573000     0.643228        NFC
# 9       9/7/2014 2014-09-07    2014  DAL  1501.041000     0.384515        NFC
# 1520    1/1/2017 2017-01-01    2016   NE  1718.551517     0.650542        AFC
# 1521    1/1/2017 2017-01-01    2016  BAL  1507.947141     0.421911        AFC
# 1522    1/1/2017 2017-01-01    2016  JAX  1325.971989     0.190259        AFC
# 1523    1/1/2017 2017-01-01    2016  CHI  1337.688188     0.232166        NFC
# 1524    1/1/2017 2017-01-01    2016  HOU  1502.411495     0.532654        AFC
# 1525    1/1/2017 2017-01-01    2016  CAR  1544.287817     0.471124        NFC
# 1526    1/1/2017 2017-01-01    2016  CLE  1252.817835     0.072217        AFC
# 1527    1/1/2017 2017-01-01    2016  DAL  1655.388965     0.658204        NFC
# 1528    1/1/2017 2017-01-01    2016  BUF  1509.964937     0.580447        AFC
# 1529    1/1/2017 2017-01-01    2016  SEA  1604.816349     0.815789        NFC
# 1530    1/1/2017 2017-01-01    2016  NYG  1536.451929     0.413813        NFC
# 1531    1/1/2017 2017-01-01    2016  OAK  1598.495825     0.471563        AFC
# 1532    1/1/2017 2017-01-01    2016   NO  1503.631595     0.244586        NFC
# 1533    1/1/2017 2017-01-01    2016   KC  1670.948997     0.751136        AFC
# 1534    1/1/2017 2017-01-01    2016  ARI  1526.385953     0.625822        NFC
# 1535    1/1/2017 2017-01-01    2016   GB  1593.030315     0.488201        NFC
#
#        division
# 0      NFC West
# 1      NFC East
# 2     AFC North
# 3     AFC North
# 4     NFC South
# 5      AFC West
# 6      NFC West
# 7     NFC South
# 8     NFC North
# 9      NFC East
# 10    AFC South
# 11     AFC West
# 12     AFC East
# 13     AFC East
# 14     NFC West
# 15    NFC North
# 16    AFC North
# 17     AFC East
# 18    NFC South
# 19    AFC North
# 20     NFC East
# 21    AFC North
# 22     AFC West
# 23    NFC North
# 24    NFC North
# 25     NFC West
# 26     NFC East
# 27     AFC West
# 28    AFC South
# 29    NFC South
# ...         ...
# 1506   AFC East
# 1507  AFC South
# 1508  NFC South
# 1509  NFC North
# 1510   AFC East
# 1511   AFC West
# 1512  AFC South
# 1513  NFC South
# 1514   NFC West
# 1515   NFC West
# 1516  AFC North
# 1517  AFC North
# 1518   AFC West
# 1519  NFC North
# 1520   AFC East
# 1521  AFC North
# 1522  AFC South
# 1523  NFC North
# 1524  AFC South
# 1525  NFC South
# 1526  AFC North
# 1527   NFC East
# 1528   AFC East
# 1529   NFC West
# 1530   NFC East
# 1531   AFC West
# 1532  NFC South
# 1533   AFC West
# 1534   NFC West
# 1535  NFC North
#
# [1536 rows x 8 columns]

# %%
# Check for nulls
merged.isnull().sum()
# Out:
# date           0
# datetime       0
# season         0
# team           0
# elo            0
# probability    0
# conference     0
# division       0
# dtype: int64

# %%
merged.to_csv('data/nfl_elo.csv', index=False)
